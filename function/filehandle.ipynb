# %%
print("hello")
# Out:
# hello

# %%
def count
# Out:
#   Cell In[7], line 1
#     def count
#              ^
# SyntaxError: expected '('

# %%
f=open("data.txt","w")
f.close()

# %%
f=open("data.txt","w")
f.write("varsha")
f.close()

# %%
f=open("data.txt","w")
def count_vowels(filename):
    vowel="aeiouAEIOU"
    count=0
    with open(filename,"r")as f:
        for line in f:
            count+=sum(1 for ch in line if ch in vowels)
            return count
    print(count_vowels("data.txt"))

# %%
from collections import Counter

def word_frequency(filename):
    with open(filename, "r") as f:
        words = f.read().split()
    return Counter(words)

print(word_frequency("data.txt"))
# Out:
# Counter()

# %%
def replace_word(filename, old, new):
    with open(filename, "r") as f:
        content = f.read()
    content = content.replace(old, new)
    with open(filename, "w") as f:
        f.write(content)

replace_word("data.txt", "hello", "hi")

# %%
def remove_blank(filename):
    with open(filename,"r") as f :
     lines=f.readlines()
    with open(filename,"w") as f:
        for line in lines:
            if line.strip():
                f .write(line)
                remove_blank("data.txt")

# %%
def unique_word(filename):
    with open (filename,"r") as f:
        words=f.read().split()
    return set(words)
    print(unique_words("data.txt"))

# %%
def mrege_file(file1 , file2,output):
  with open(file1,"r")as f1,open(file2,"r",)as f2,open(output,"w")as out:
    out.write(f1.read())
    out.write(f2.read())

    merge_file("file.txt","file2.txt","merge,txt")

# %%
def reverse_file(filename):
    with open(filename, "r") as f:
        content = f.read()
    with open(filename, "w") as f:
        f.write(content[::-1])

reverse_file("data.txt")

# %%
def last_five_lines(filename):
    with open(filename, "r") as f:
        lines = f.readlines()
    return lines[-5:]

print("".join(last_five_lines("data.txt")))

# %%
with open("data.txt", "r") as f:
    data = f.read()

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Varsha", 20)
print(s1.name, s1.age)
# Out:
# Varsha 20

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

c1 = Car("Toyota", "Corolla")
c2 = Car("Honda", "Civic")
print(c1.brand, c1.model)
print(c2.brand, c2.model)
# Out:
# Toyota Corolla
# Honda Civic

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

b1 = Book("Python Basics", "John Doe")
print(b1.title, b1.author)
# Out:
# Python Basics John Doe

# %%
class Employee:
    def __init__(self, emp_id, name):
        self.emp_id = emp_id
        self.name = name

e1 = Employee(101, "Varsha")
print(e1.emp_id, e1.name)
# Out:
# 101 Varsha

# %%
class MObile:
    def __init__(self , brand , price):
        self.brand = brand
        self.price = price 
m1= MObile("samasung",150000)
print(m1.brand , m1.price)
# Out:
# samasung 150000

# %%
class Student:
    def __init__(self, name, marks):
        self.name=name
        self.marks=marks

s1=Student("varsha",95)
print(s1.name,s1.marks)
# Out:
# varsha 95

# %%
class Laptop:
    def __init__(self, brand, price):
        self.brand = brand
        self.price = price

    def display(self):
        print("Brand:", self.brand, "Price:", self.price)

l1=Laptop("dell",55000)
l1.display()
# Out:
# Brand: dell Price: 55000

# %%
class Person:
    def __init__(self, name , age ):
     self.name=name
     
     self.age=age

p1=Person("varsha",20)
print(p1.name,p1.age)
# Out:
# varsha 20

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

acc = BankAccount(5000)
print("Balance:", acc.balance)
# Out:
# Balance: 5000

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Varsha", 21)
print(s1.name, s1.age)
# Out:
# Varsha 21

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width

    def area(self):
        return self.length*self.width
    
r1=Rectangle(10,5)
print(r1.area())
# Out:
# 50

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius * self.radius

c1 = Circle(7)
print("Circle Area:", c1.area())
# Out:
# Circle Area: 153.86

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

e1 = Employee("Amit", 50000)
print(e1.name, e1.salary)
# Out:
# Amit 50000

# %%
class Movie:
    def __init__(self, title, rating):
        self.title = title
        self.rating = rating

m1 = Movie("Inception", 9.0)
print(m1.title, m1.rating)
# Out:
# Inception 9.0

# %%
class Animal:
    def speak(self):
        print("animal speaks")

class Dog(Animal):
    def speak(self):
        print("dog barks")
    
d=Dog()
d.speak()
# Out:
# dog barks

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

class Bike(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model

b = Bike("Honda", "Shine")
print(b.brand, b.model)
# Out:
# Honda Shine

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, rollno):
        super().__init__(name)
        self.rollno = rollno

s = Student("Varsha", 101)
print(s.name, s.rollno)
# Out:
# Varsha 101

# %%
class Shape:
    def area(self):
        return 0

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width

r = Rectangle(8, 4)
print("Rectangle Area:", r.area())
# Out:
# Rectangle Area: 32

# %%
class Employee:
    def __init__(self, name):
        self.name = name

class Manager(Employee):
    def __init__(self, name, department):
        super().__init__(name)
        self.department = department

m = Manager("Ravi", "IT")
print(m.name, m.department)
# Out:
# Ravi IT

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s = Student("Varsha", 21)
print(s.name, s.age)
# Out:
# Varsha 21

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Teacher(Person):
    def __init__(self, name, subject):
        super().__init__(name)
        self.subject = subject

t = Teacher("Anita", "Math")
print(t.name, t.subject)
# Out:
# Anita Math

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
    
    def display(self):
        print("Balance:", self.balance)

acc = BankAccount(1000)
acc.deposit(500)
acc.display()
# Out:
# Balance: 1500

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model

c = Car("Toyota", "Corolla")
print(c.brand, c.model)
# Out:
# Toyota Corolla

# %%
class Library:
    def __init__(self, name):
        self.name = name

class Book(Library):
    def __init__(self, name, title, author):
        super().__init__(name)
        self.title = title
        self.author = author

b = Book("City Library", "Python Basics", "Guido")
print(b.name, b.title, b.author)
# Out:
# City Library Python Basics Guido

# %%
class Student:
    def __init__(self, name, age):
        self.__name = name   # private
        self.age = age
    
    def set_name(self, name):
        self.__name = name
    
    def get_name(self):
        return self.__name

s = Student("Varsha", 21)
print(s.get_name(), s.age)
s.set_name("Anita")
print(s.get_name())
# Out:
# Varsha 21
# Anita

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary

    def set_salary(self,salary):
        self.__salary=salary

    def get_salary(self):
        return self.__salary
    
e=Employee("amit",50000)
print(e.name,e.get_salary())
e.set_salary(6000)
print(e.get_salary())
# Out:
# amit 50000
# 6000

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance
    
    def deposit(self, amount):
        self.__balance += amount
    
    def display_balance(self):
        print("Balance:", self.__balance)

acc = BankAccount(1000)
acc.deposit(500)
acc.display_balance()
# Out:
# Balance: 1500

# %%
class Book:
    def __init__(self, title, price):
        self.title = title
        self.__price = price
    
    def set_price(self, price):
        self.__price = price
    
    def get_price(self):
        return self.__price

b = Book("Python Basics", 300)
print(b.title, b.get_price())
b.set_price(350)
print(b.get_price())
# Out:
# Python Basics 300
# 350

# %%
class Mobile:
    def __init__(self, brand, price):
        self.__brand = brand
        self.price = price
    
    def set_brand(self, brand):
        self.__brand = brand
    
    def get_brand(self):
        return self.__brand

m = Mobile("Samsung", 15000)
print(m.get_brand(), m.price)
m.set_brand("Apple")
print(m.get_brand())
# Out:
# Samsung 15000
# Apple

# %%
class Laptop:
    def __init__(self, brand, price):
        self.__brand = brand
        self.__price = price
    
    def set_brand(self, brand):
        self.__brand = brand
    
    def get_brand(self):
        return self.__brand
    
    def set_price(self, price):
        self.__price = price
    
    def get_price(self):
        return self.__price
    
l = Laptop("Dell", 50000)
print(l.get_brand(), l.get_price())
l.set_price(55000)
print(l.get_price())
# Out:
# Dell 50000
# 55000

# %%
class Car:
    def __init__(self, brand, speed):
        self.brand = brand
        self.__speed = speed
    
    def set_speed(self, speed):
        self.__speed = speed
    
    def get_speed(self):
        return self.__speed

c = Car("Toyota", 120)
print(c.brand, c.get_speed())
c.set_speed(150)
print(c.get_speed())
# Out:
# Toyota 120
# 150

# %%
class Movie:
    def __init__(self, title, rating):
        self.title = title
        self.__rating = rating
    
    def set_rating(self, rating):
        self.__rating = rating
    
    def get_rating(self):
        return self.__rating

m = Movie("Inception", 9.0)
print(m.title, m.get_rating())
m.set_rating(9.5)
print(m.get_rating())
# Out:
# Inception 9.0
# 9.5

# %%
class Hospital:
    def __init__(self, patient_name):
        self.__patient_name = patient_name
    
    def set_patient_name(self, name):
        self.__patient_name = name
    
    def get_patient_name(self):
        return self.__patient_name

h = Hospital("Rahul")
print(h.get_patient_name())
h.set_patient_name("Sita")
print(h.get_patient_name())
# Out:
# Rahul
# Sita

# %%
class ATM:
    def __init__(self, balance=0):
        self.__balance = balance
    
    def deposit(self, amount):
        self.__balance += amount
    
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient balance")
    
    def check_balance(self):
        print("Balance:", self.__balance)

atm = ATM(2000)
atm.deposit(1000)
atm.check_balance()
atm.withdraw(500)
atm.check_balance()
atm.withdraw(5000)
# Out:
# Balance: 3000
# Withdrawn: 500
# Balance: 2500
# Insufficient balance

# %%
class Animal:
    def Sound(self):
        print("animal make a sound")

class Dog(Animal):
    def sound(self):
        print("dog barks")

class Cat(Animal):
    def sound(self):
        print("cat sound")

d=Dog()
c=Cat()
d.sound()
c.sound()
# Out:
# dog barks
# cat sound

# %%
class Person:
    def work(self):
        print("Person works")

class Student(Person):
    def work(self):
        print("Student studies")

class Teacher(Person):
    def work(self):
        print("Teacher teaches")

s = Student()
t = Teacher()
s.work()
t.work()
# Out:
# Student studies
# Teacher teaches

# %%
class Shape:
    def draw(self):
        print("Drawing a shape")

class Circle(Shape):
    def draw(self):
        print("Drawing a circle")

class Rectangle(Shape):
    def draw(self):
        print("Drawing a rectangle")

c = Circle()
r = Rectangle()
c.draw()
r.draw()
# Out:
# Drawing a circle
# Drawing a rectangle

# %%
class Bird:
    def fly(self):
        print("Bird flies")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies low")

class Peacock(Bird):
    def fly(self):

        print("Peacock flies short distance")

s = Sparrow()
p = Peacock()
s.fly()
p.fly()
# Out:
# Sparrow flies low
# Peacock flies short distance

# %%
class Payment:
    def pay(self):
        print("Payment method")

class Cash(Payment):
    def pay(self):
        print("Paid with cash")

class Card(Payment):
    def pay(self):
        print("Paid with card")

class UPI(Payment):
    def pay(self):
        print("Paid via UPI")

c = Cash()
cr = Card()
u = UPI()
c.pay()
cr.pay()
# Out:
# Paid with cash
# Paid with card

# %%
class Employee:
    def salary(self):
        print("Employee salary")

class Manager(Employee):
    def salary(self):
        print("Manager salary is high")

class Developer(Employee):
    def salary(self):
        print("Developer salary is medium")

m = Manager()
d = Developer()
m.salary()
d.salary()
# Out:
# Manager salary is high
# Developer salary is medium

# %%
class Fruit:
    def taste(self):
        print("Fruit taste")

class Apple(Fruit):
    def taste(self):
        print("Apple tastes sweet")

class Mango(Fruit):
    def taste(self):
        print("Mango tastes tangy and sweet")

a = Apple()
m = Mango()
a.taste()
m.taste()
# Out:
# Apple tastes sweet
# Mango tastes tangy and sweet

# %%
class Notification:
    def send(self):
        print("Sending notification")

class Email(Notification):
    def send(self):
        print("Sending Email")

class SMS(Notification):
    def send(self):
        print("Sending SMS")

class WhatsApp(Notification):
    def send(self):
        print("Sending WhatsApp message")

e = Email()
s = SMS()
w = WhatsApp()
e.send()
s.send()
w.send()
# Out:
# Sending Email
# Sending SMS
# Sending WhatsApp message

# %%
class Dog:
    def sound(self):
        print("Dog barks")

class Cat:
    def sound(self):
        print("Cat meows")

class Cow:
    def sound(self):
        print("Cow moos")

def animal_sound(animal):
    animal.sound()

# Polymorphism in action
dog = Dog()
cat = Cat()
cow = Cow()

animal_sound(dog)
animal_sound(cat)
animal_sound(cow)
# Out:
# Dog barks
# Cat meows
# Cow moos
